# %% [markdown]
# Data Science In Python
# =======================
# Overview
# --------
# **Cambridge, MA, January 9th 2017**
# <br>
#
# <center>
# <img src=http://ijstokes-public.s3.amazonaws.com/dspyr/img/AnacondaCIO_Logo width=400 />
# </center>
#
# **Copyrighted Continuum Analytics**
#
# <br>
# GitHub: https://github.com/Harvard-IACS/computefest2017-pythonml
#
# Anaconda Cloud: https://anaconda.org/ijstokes/python-cf17-01-overview/notebook
# <br>
#
# Taught by:
#
# * Ian Stokes-Rees [ijstokes@continuum.io](mailto:ijstokes@continuum.io)
#     * Twitter: [@ijstokes](http://twitter.com/ijstokes)
#     * About.Me: [http://about.me/ijstokes](http://about.me/ijstokes)
#     * LinkedIn: [http://linkedin.com/in/ijstokes](http://linkedin.com/in/ijstokes)

# %% [markdown]
# Setup
# ===
# * Download Anaconda 4.2 for Python 2.7
# * Start *Anaconda Navigator* from your desktop
#     * green ouroboros ring -- yes, that's what it is
# * Make sure it says *Python 2.7* in the top row
#     * if not, click on *Environment* then *New Environment* and create one called `ana42py37` using Python 2.7
#     * then search for "Anaconda" and install that meta-package
#     * **but** note that this will kill the event APs: 300+ MB to do this.
# * Launch Notebook (may require "upgrade" or "install" first)
# * Alternative for command line geeks:
#
# ```bash
# conda create -n ana42py27 anaconda python=2.7
# source activate ana42py27
# mkdir pythonds
# cd pythonds
# jupyter notebook
# ```

# %% [markdown]
# Anaconda Navigator & Jupyter Notebooks
# ------------------------------------------------------------
# ![Anaconda Navigator](http://ijstokes-public.s3.amazonaws.com/dspyr/img/screenshot_anaconda_navigator.png)

# %% [markdown]
# Fundamental Jupyter operations
# ------------------------------
# * Cells
# * Execute
# * Stop
# * Insert new cell
# * Re-order cells
# * Clear output
# * Restart kernel

# %%
x = 42
y = 15
z = 9

# %%
x, y, z

# %%
import sys

# %%
sys.prefix

# %% [markdown]
# Injest, analyze, and clean data with Pandas
# -----------------------------------------------

# %% [markdown]
# ### Get Your Hands Dirty, and Code First
#
# Once upon a time the coding part was complicated, time consuming, and only possible by experts who were often far removed from the line-of-business objectives they are trying to serve.  Today you need to move beyond spreadsheets for data insights and need to be empowered to find answers yourself, with little or no reference to a distant analytics team.
#
# Anaconda was created to empower anyone who can use Excel to have in their hands the tools they need to injest data, analyze it, visualize it, build interactive apps, and deploy production analysis models at scale.
#
# So I will start by demonstrating a simple analysis workflow of a well known sample data set of 400 cars from the 1970s.

# %%
import pandas as pd

pd.set_option("display.max_rows",10)

# %% [markdown]
# Normally we wouldn't read data this way, but this is some sample data that is bundled with Bokeh for convenience

# %%
from bokeh.sampledata.autompg import autompg

# %% [markdown]
# In Python just typing the name of a variable will show you a "representation" of that variable. In the case of a `pandas.DataFrame` we'll see a data table.

# %%
autompg
# Out:
#       mpg  cyl  displ   hp  weight  accel  yr  origin  \
# 0    18.0    8  307.0  130    3504   12.0  70       1
# 1    15.0    8  350.0  165    3693   11.5  70       1
# 2    18.0    8  318.0  150    3436   11.0  70       1
# 3    16.0    8  304.0  150    3433   12.0  70       1
# 4    17.0    8  302.0  140    3449   10.5  70       1
# ..    ...  ...    ...  ...     ...    ...  ..     ...
# 387  27.0    4  140.0   86    2790   15.6  82       1
# 388  44.0    4   97.0   52    2130   24.6  82       2
# 389  32.0    4  135.0   84    2295   11.6  82       1
# 390  28.0    4  120.0   79    2625   18.6  82       1
# 391  31.0    4  119.0   82    2720   19.4  82       1
#
#                           name
# 0    chevrolet chevelle malibu
# 1            buick skylark 320
# 2           plymouth satellite
# 3                amc rebel sst
# 4                  ford torino
# ..                         ...
# 387            ford mustang gl
# 388                  vw pickup
# 389              dodge rampage
# 390                ford ranger
# 391                 chevy s-10
#
# [392 rows x 9 columns]

# %% [markdown]
# Look at the data, sorted by fuel efficiency dimension `mpg`

# %%
type(autompg)
# Out:
# pandas.core.frame.DataFrame

# %%
autompg.sort_values(by='mpg')
# Out:
#       mpg  cyl  displ   hp  weight  accel  yr  origin                  name
# 28    9.0    8  304.0  193    4732   18.5  70       1              hi 1200d
# 26   10.0    8  307.0  200    4376   15.0  70       1             chevy c20
# 25   10.0    8  360.0  215    4615   14.0  70       1             ford f250
# 27   11.0    8  318.0  210    4382   13.5  70       1            dodge d200
# 123  11.0    8  350.0  180    3664   11.0  73       1      oldsmobile omega
# ..    ...  ...    ...  ...     ...    ...  ..     ...                   ...
# 324  43.4    4   90.0   48    2335   23.7  80       2    vw dasher (diesel)
# 388  44.0    4   97.0   52    2130   24.6  82       2             vw pickup
# 323  44.3    4   90.0   48    2085   21.7  80       2  vw rabbit c (diesel)
# 327  44.6    4   91.0   67    1850   13.8  80       3   honda civic 1500 gl
# 320  46.6    4   86.0   65    2110   17.9  80       3             mazda glc
#
# [392 rows x 9 columns]

# %% [markdown]
# Notice the first word in each name entry is the *make*.  We'll use this to add a `make` field to the `pandas.DataFrame` object:

# %%
autompg['make'] = pd.Series((n.split()[0] for n in autompg.name), 
                            index=autompg.index)

# %% [markdown]
# Let's look at a sorted list of this new dimension

# %%
autompg
# Out:
#       mpg  cyl  displ   hp  weight  accel  yr  origin  \
# 0    18.0    8  307.0  130    3504   12.0  70       1
# 1    15.0    8  350.0  165    3693   11.5  70       1
# 2    18.0    8  318.0  150    3436   11.0  70       1
# 3    16.0    8  304.0  150    3433   12.0  70       1
# 4    17.0    8  302.0  140    3449   10.5  70       1
# ..    ...  ...    ...  ...     ...    ...  ..     ...
# 387  27.0    4  140.0   86    2790   15.6  82       1
# 388  44.0    4   97.0   52    2130   24.6  82       2
# 389  32.0    4  135.0   84    2295   11.6  82       1
# 390  28.0    4  120.0   79    2625   18.6  82       1
# 391  31.0    4  119.0   82    2720   19.4  82       1
#
#                           name       make
# 0    chevrolet chevelle malibu  chevrolet
# 1            buick skylark 320      buick
# 2           plymouth satellite   plymouth
# 3                amc rebel sst        amc
# 4                  ford torino       ford
# ..                         ...        ...
# 387            ford mustang gl       ford
# 388                  vw pickup         vw
# 389              dodge rampage      dodge
# 390                ford ranger       ford
# 391                 chevy s-10      chevy
#
# [392 rows x 10 columns]

# %%
sorted(autompg.make.unique())
# Out:
# ['amc',
#  'audi',
#  'bmw',
#  'buick',
#  'cadillac',
#  'capri',
#  'chevroelt',
#  'chevrolet',
#  'chevy',
#  'chrysler',
#  'datsun',
#  'dodge',
#  'fiat',
#  'ford',
#  'hi',
#  'honda',
#  'maxda',
#  'mazda',
#  'mercedes',
#  'mercedes-benz',
#  'mercury',
#  'nissan',
#  'oldsmobile',
#  'opel',
#  'peugeot',
#  'plymouth',
#  'pontiac',
#  'renault',
#  'saab',
#  'subaru',
#  'toyota',
#  'toyouta',
#  'triumph',
#  'vokswagen',
#  'volkswagen',
#  'volvo',
#  'vw']

# %% [markdown]
# Several makes have spelling errors or inconsistencies. Pandas can help us fix those in place:

# %%
autompg.loc[autompg.make == 'chevroelt', 'make'] = 'chevrolet'
autompg.loc[autompg.make == 'chevy',     'make'] = 'chevrolet'
autompg.loc[autompg.make == 'maxda',     'make'] = 'mazda'
autompg.loc[autompg.make == 'mercedes',  'make'] = 'mercedes-benz'
autompg.loc[autompg.make == 'toyouta',   'make'] = 'toyota'
autompg.loc[autompg.make == 'vokswagen', 'make'] = 'volkswagen'
autompg.loc[autompg.make == 'vw',        'make'] = 'volkswagen'

# %%
sorted(autompg.make.unique())
# Out:
# ['amc',
#  'audi',
#  'bmw',
#  'buick',
#  'cadillac',
#  'capri',
#  'chevrolet',
#  'chrysler',
#  'datsun',
#  'dodge',
#  'fiat',
#  'ford',
#  'hi',
#  'honda',
#  'mazda',
#  'mercedes-benz',
#  'mercury',
#  'nissan',
#  'oldsmobile',
#  'opel',
#  'peugeot',
#  'plymouth',
#  'pontiac',
#  'renault',
#  'saab',
#  'subaru',
#  'toyota',
#  'triumph',
#  'volkswagen',
#  'volvo']

# %%
with pd.option_context('display.max_rows', 999):
    print(autompg.groupby('make').size())
# Out:
# make
# amc              27
# audi              7
# bmw               2
# buick            17
# cadillac          2
# capri             1
# chevrolet        47
# chrysler          6
# datsun           23
# dodge            28
# fiat              8
# ford             48
# hi                1
# honda            13
# mazda            12
# mercedes-benz     3
# mercury          11
# nissan            1
# oldsmobile       10
# opel              4
# peugeot           8
# plymouth         31
# pontiac          16
# renault           3
# saab              4
# subaru            4
# toyota           26
# triumph           1
# volkswagen       22
# volvo             6
# dtype: int64

# %% [markdown]
# Visualize data with Bokeh
# -----------------------------

# %%
from bokeh.charts import Scatter, Histogram
from bokeh.models import HoverTool
from bokeh.io     import output_notebook, show

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a85fd227-f9ef-46c6-b745-f62ea4cf0f7d">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# What trend do we observe in this data set?
# What was happening through the 1970s that might cause this?

# %%
s = Scatter(data=autompg, x='yr', y='mpg', height=400)
show(s)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="e9055b94-55ba-4e76-844f-956b68ebc39f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#e9055b94-55ba-4e76-844f-956b68ebc39f").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e9055b94-55ba-4e76-844f-956b68ebc39f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e9055b94-55ba-4e76-844f-956b68ebc39f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"7eef1672-6354-4eb4-b4bb-126c46d866c2":{"roots":{"references":[{"attributes":{"callback":null,"end":50.36,"start":5.24},"id":"e2d5ecc5-3d56-4316-985b-8ce8109600d7","type":"Range1d"},{"attributes":{},"id":"c527beba-ab06-46bb-abdb-d230f2ff45d3","type":"ToolEvents"},{"attributes":{"data_source":{"id":"c3b9e371-1ee6-48ee-824d-0a5b18d9730b","type":"ColumnDataSource"},"glyph":{"id":"93da7e4f-b2cd-4cc6-8a9c-01847e0d6a5a","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"848c7322-e15a-4a76-8488-76959132f1ea","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"1cdca631-e01b-4b8f-812e-35eba0e6e817","subtype":"Chart","type":"Plot"},"ticker":{"id":"aeab051d-fc1d-42e4-8553-51e5d299a92d","type":"BasicTicker"}},"id":"91069337-3ebc-4492-b5ac-34e7d3fd0091","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"f725f8fc-697e-4012-bc5f-7972ca07551f","type":"BoxAnnotation"},{"attributes":{"dimension":1,"plot":{"id":"1cdca631-e01b-4b8f-812e-35eba0e6e817","subtype":"Chart","type":"Plot"},"ticker":{"id":"e5bcd81d-ee78-41e9-ad2f-b61a46b42b1f","type":"BasicTicker"}},"id":"4c17562c-bc56-479a-aea5-117c538e4dd9","type":"Grid"},{"attributes":{},"id":"aeab051d-fc1d-42e4-8553-51e5d299a92d","type":"BasicTicker"},{"attributes":{},"id":"acf93e4c-5bcc-4cc9-b85b-eeb0eb413bd6","type":"BasicTickFormatter"},{"attributes":{},"id":"e5bcd81d-ee78-41e9-ad2f-b61a46b42b1f","type":"BasicTicker"},{"attributes":{"location":"top_left","plot":{"id":"1cdca631-e01b-4b8f-812e-35eba0e6e817","subtype":"Chart","type":"Plot"}},"id":"02b02e56-bdb7-42f6-9d33-f3294908aa38","type":"Legend"},{"attributes":{"axis_label":"mpg","formatter":{"id":"b2677c3c-73b3-4c74-a7dd-75747d1c825b","type":"BasicTickFormatter"},"plot":{"id":"1cdca631-e01b-4b8f-812e-35eba0e6e817","subtype":"Chart","type":"Plot"},"ticker":{"id":"e5bcd81d-ee78-41e9-ad2f-b61a46b42b1f","type":"BasicTicker"}},"id":"0611368f-bb08-4138-8c3e-5da6497dedd9","type":"LinearAxis"},{"attributes":{"plot":{"id":"1cdca631-e01b-4b8f-812e-35eba0e6e817","subtype":"Chart","type":"Plot"}},"id":"7fe8befa-5e3d-4d66-afa9-473f773127b1","type":"PanTool"},{"attributes":{"plot":{"id":"1cdca631-e01b-4b8f-812e-35eba0e6e817","subtype":"Chart","type":"Plot"}},"id":"8cc4fb37-7af7-427a-8288-9b7568798983","type":"SaveTool"},{"attributes":{"plot":null,"text":null},"id":"a2122c18-2cb4-4a36-92f4-b85c5f940a51","type":"Title"},{"attributes":{"plot":{"id":"1cdca631-e01b-4b8f-812e-35eba0e6e817","subtype":"Chart","type":"Plot"}},"id":"be6c9970-2d4f-4368-b87f-ff53fa8948b9","type":"HelpTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"7fe8befa-5e3d-4d66-afa9-473f773127b1","type":"PanTool"},{"id":"cde56e77-ad2b-4297-af0a-53586572f66d","type":"WheelZoomTool"},{"id":"2f8c9f1a-66e6-48d3-b795-2fc4d57cc977","type":"BoxZoomTool"},{"id":"8cc4fb37-7af7-427a-8288-9b7568798983","type":"SaveTool"},{"id":"54f4f95b-09dc-40e6-be8a-fc20cb50dd85","type":"ResetTool"},{"id":"be6c9970-2d4f-4368-b87f-ff53fa8948b9","type":"HelpTool"}]},"id":"96dde7a1-35d1-4a19-8ea1-042ee6e45d74","type":"Toolbar"},{"attributes":{},"id":"b2677c3c-73b3-4c74-a7dd-75747d1c825b","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"1cdca631-e01b-4b8f-812e-35eba0e6e817","subtype":"Chart","type":"Plot"}},"id":"cde56e77-ad2b-4297-af0a-53586572f66d","type":"WheelZoomTool"},{"attributes":{"axis_label":"yr","formatter":{"id":"acf93e4c-5bcc-4cc9-b85b-eeb0eb413bd6","type":"BasicTickFormatter"},"plot":{"id":"1cdca631-e01b-4b8f-812e-35eba0e6e817","subtype":"Chart","type":"Plot"},"ticker":{"id":"aeab051d-fc1d-42e4-8553-51e5d299a92d","type":"BasicTicker"}},"id":"59e60050-7cc5-4ed2-a6e7-aeda0c16a7dc","type":"LinearAxis"} ...

# %% [markdown]
# Let's just look at one make from each of the US, Germany, and Japan

# %%
'ford volkswagen honda'.split()
# Out:
# ['ford', 'volkswagen', 'honda']

# %%
s = Scatter(data=autompg[autompg.make.isin('ford volkswagen honda'.split())],
            x='yr', y='mpg', color='make', height=400)
show(s)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="987b4423-d664-4a9a-b51a-393973fd3288"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#987b4423-d664-4a9a-b51a-393973fd3288").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("987b4423-d664-4a9a-b51a-393973fd3288");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '987b4423-d664-4a9a-b51a-393973fd3288' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"683f955e-7eb8-4b08-982f-5ef1a8a76ced":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"8408a06b-4341-4b4b-b6f4-3b9f875d9ef5","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"4736b256-21f0-41c5-9fe2-fdcb6f4c4d5d","subtype":"Chart","type":"Plot"}},"id":"1ca501cf-ee1e-4b52-96eb-8c6a8955e104","type":"PanTool"},{"attributes":{"legends":[["ford",[{"id":"51d47878-7295-4ba0-83fd-fbdb57defc42","type":"GlyphRenderer"}]],["volkswagen",[{"id":"de94a460-edfe-4719-939f-60ba7cb523e6","type":"GlyphRenderer"}]],["honda",[{"id":"ba913cdc-d797-4e52-8719-b03be5707cb9","type":"GlyphRenderer"}]]],"location":"top_left","plot":{"id":"4736b256-21f0-41c5-9fe2-fdcb6f4c4d5d","subtype":"Chart","type":"Plot"}},"id":"854ae520-c1a8-4826-ac41-6c4229d49c15","type":"Legend"},{"attributes":{"below":[{"id":"3c47c8cf-6ef0-4eef-b7de-568abb1e3a22","type":"LinearAxis"}],"height":400,"left":[{"id":"caad19d0-f110-4ae5-b9b1-97661d6b42d9","type":"LinearAxis"}],"renderers":[{"id":"8408a06b-4341-4b4b-b6f4-3b9f875d9ef5","type":"BoxAnnotation"},{"id":"51d47878-7295-4ba0-83fd-fbdb57defc42","type":"GlyphRenderer"},{"id":"de94a460-edfe-4719-939f-60ba7cb523e6","type":"GlyphRenderer"},{"id":"ba913cdc-d797-4e52-8719-b03be5707cb9","type":"GlyphRenderer"},{"id":"854ae520-c1a8-4826-ac41-6c4229d49c15","type":"Legend"},{"id":"3c47c8cf-6ef0-4eef-b7de-568abb1e3a22","type":"LinearAxis"},{"id":"caad19d0-f110-4ae5-b9b1-97661d6b42d9","type":"LinearAxis"},{"id":"f1611a2c-ff2c-4442-867f-829d090a442d","type":"Grid"},{"id":"1483fd51-5417-4fff-9b55-e7595335c8b0","type":"Grid"}],"title":{"id":"7eca8dec-ee7e-4bd9-9734-418f34ab3e05","type":"Title"},"tool_events":{"id":"2f765d6a-3407-4f45-a8ed-c0f5a8d0a919","type":"ToolEvents"},"toolbar":{"id":"0a73a739-409f-4fdf-8b41-95ce518d4d4d","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"fb411749-ebe4-43e9-835c-bb001c7ff42a","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"9bd58c8e-2ae1-4b79-aad5-32d955edeaa5","type":"Range1d"}},"id":"4736b256-21f0-41c5-9fe2-fdcb6f4c4d5d","subtype":"Chart","type":"Plot"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"make":"honda"},{"make":"honda"},{"make":"honda"},{"make":"honda"},{"make":"honda"},{"make":"honda"},{"make":"honda"},{"make":"honda"},{"make":"honda"},{"make":"honda"},{"make":"honda"},{"make":"honda"},{"make":"honda"}],"make":["honda","honda","honda","honda","honda","honda","honda","honda","honda","honda","honda","honda","honda"],"x_values":[74,75,76,77,78,78,80,80,81,81,82,82,82],"y_values":[24.0,33.0,33.0,31.5,36.1,29.5,44.6,32.4,35.1,33.7,36.0,38.0,32.0]}},"id":"de917c6b-8e19-428a-90ee-df8ed886546a","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"a4015396-0951-4429-b2f8-71ee6c46871b","type":"ColumnDataSource"},"glyph":{"id":"1b01b262-974d-4d24-905f-e6e817ee15ed","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"de94a460-edfe-4719-939f-60ba7cb523e6","type":"GlyphRenderer"},{"attributes":{},"id":"9a2d9739-fa26-4f66-8308-fe7c4256a7ad","type":"BasicTicker"},{"attributes":{"plot":{"id":"4736b256-21f0-41c5-9fe2-fdcb6f4c4d5d","subtype":"Chart","type":"Plot"}},"id":"fb5dfbcd-725a-4f37-b048-3920e27b45e3","type":"ResetTool"},{"attributes":{"axis_label":"mpg","formatter":{"id":"c8391c62-1039-4622-9ae3-d468d8b7c278","type":"BasicTickFormatter"},"plot":{"id":"4736b256-21f0-41c5-9fe2-fdcb6f4c4d5d","subtype":"Chart","type":"Plot"},"ticker":{"id":"9a2d9739-fa26-4f66-8308-fe7c4256a7ad","type":"BasicTicker"}},"id":"caad19d0-f110-4ae5-b9b1-97661d6b42d9","type":"LinearAxis"},{"attributes":{"plot":null,"text":null},"id":"7eca8dec-ee7e-4bd9-9734-418f34ab3e05","type":"Title"},{"attr ...

# %% [markdown]
# How did we do that? With a sub-select on the `autompg` object using something called *"fancy indexing"* to select just the rows that have a make that is one of `ford volkswagen honda`.

# %%
autompg[autompg.make.isin('ford volkswagen honda'.split())]
# Out:
#       mpg  cyl  displ   hp  weight  accel  yr  origin  \
# 4    17.0    8  302.0  140    3449   10.5  70       1
# 5    15.0    8  429.0  198    4341   10.0  70       1
# 17   21.0    6  200.0   85    2587   16.0  70       1
# 19   26.0    4   97.0   46    1835   20.5  70       2
# 25   10.0    8  360.0  215    4615   14.0  70       1
# ..    ...  ...    ...  ...     ...    ...  ..     ...
# 378  32.0    4   91.0   67    1965   15.7  82       3
# 383  22.0    6  232.0  112    2835   14.7  82       1
# 387  27.0    4  140.0   86    2790   15.6  82       1
# 388  44.0    4   97.0   52    2130   24.6  82       2
# 390  28.0    4  120.0   79    2625   18.6  82       1
#
#                              name        make
# 4                     ford torino        ford
# 5                ford galaxie 500        ford
# 17                  ford maverick        ford
# 19   volkswagen 1131 deluxe sedan  volkswagen
# 25                      ford f250        ford
# ..                            ...         ...
# 378            honda civic (auto)       honda
# 383                ford granada l        ford
# 387               ford mustang gl        ford
# 388                     vw pickup  volkswagen
# 390                   ford ranger        ford
#
# [83 rows x 10 columns]

# %% [markdown]
# Use Bokeh to add some simple interactivity

# %%
autompg[autompg.make.isin('ford volkswagen honda'.split())]
# Out:
#       mpg  cyl  displ   hp  weight  accel  yr  origin  \
# 4    17.0    8  302.0  140    3449   10.5  70       1
# 5    15.0    8  429.0  198    4341   10.0  70       1
# 17   21.0    6  200.0   85    2587   16.0  70       1
# 19   26.0    4   97.0   46    1835   20.5  70       2
# 25   10.0    8  360.0  215    4615   14.0  70       1
# ..    ...  ...    ...  ...     ...    ...  ..     ...
# 378  32.0    4   91.0   67    1965   15.7  82       3
# 383  22.0    6  232.0  112    2835   14.7  82       1
# 387  27.0    4  140.0   86    2790   15.6  82       1
# 388  44.0    4   97.0   52    2130   24.6  82       2
# 390  28.0    4  120.0   79    2625   18.6  82       1
#
#                              name        make
# 4                     ford torino        ford
# 5                ford galaxie 500        ford
# 17                  ford maverick        ford
# 19   volkswagen 1131 deluxe sedan  volkswagen
# 25                      ford f250        ford
# ..                            ...         ...
# 378            honda civic (auto)       honda
# 383                ford granada l        ford
# 387               ford mustang gl        ford
# 388                     vw pickup  volkswagen
# 390                   ford ranger        ford
#
# [83 rows x 10 columns]

# %%
s = Scatter(data=autompg[autompg.make.isin('ford volkswagen honda'.split())],
            x='yr', y='mpg', color='make',
            height=400, width=800,
            title='Fuel efficiency of selected vehicles from 1970-1982',
            tools='hover, box_zoom, lasso_select, save, reset')

hover = s.select(dict(type=HoverTool))

hover.tooltips = [
      ('Make','@make'),
      ('MPG', '@mpg'),
      ('hp',  '@hp')
    ]

show(s)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="9a57b08b-b1bb-457c-8f35-d29d5d32f56a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#9a57b08b-b1bb-457c-8f35-d29d5d32f56a").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9a57b08b-b1bb-457c-8f35-d29d5d32f56a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9a57b08b-b1bb-457c-8f35-d29d5d32f56a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"30f71284-5242-45a6-8a8c-18b68d94646b":{"roots":{"references":[{"attributes":{"plot":{"id":"99531a51-adcd-447d-a9f3-4f2cf4ae41c3","subtype":"Chart","type":"Plot"}},"id":"2486ca3f-75ec-4e09-925c-9b388d78b7b3","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"}],"make":["volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen"],"x_values":[70,71,72,72,73,74,75,75,76,76,77,77,78,78,79,80,80,80,80,81,82,82],"y_values":[26.0,27.0,23.0,22.0,26.0,26.0,25.0,29.0,29.0,29.5,29.0,30.5,43.1,31.5,31.9,41.5,44.3,43.4,29.8,33.0,36.0,44.0]}},"id":"e8403b7c-136f-4576-8756-023048a85363","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"6d84b1a8-fd7f-4cc7-b061-73d886688b0f","type":"LinearAxis"}],"height":400,"left":[{"id":"c5d0efd5-67ff-495d-880e-a395c1dd0c11","type":"LinearAxis"}],"renderers":[{"id":"27acf454-3032-403a-9325-0fb2f9f1a292","type":"BoxAnnotation"},{"id":"831b769a-dd18-4ba5-abd5-b79e1f04897f","type":"PolyAnnotation"},{"id":"59a602c3-6927-4da2-b443-704cc980e5c2","type":"GlyphRenderer"},{"id":"0bfbac3d-4ad4-4ad4-8edb-22eaf41a42ed","type":"GlyphRenderer"},{"id":"ae56caba-d9c4-4a08-9aef-3b261d8fc815","type":"GlyphRenderer"},{"id":"3116f2e6-7d9f-4b2e-b07b-62952a79f544","type":"Legend"},{"id":"6d84b1a8-fd7f-4cc7-b061-73d886688b0f","type":"LinearAxis"},{"id":"c5d0efd5-67ff-495d-880e-a395c1dd0c11","type":"LinearAxis"},{"id":"efc81310-1aac-423f-b136-cf4dd4a091c3","type":"Grid"},{"id":"131e1001-c2ff-4ff9-ba05-392a889486ea","type":"Grid"}],"title":{"id":"6d972a12-611a-4e92-960b-b30b3e6a76f2","type":"Title"},"tool_events":{"id":"09d08681-77c7-4078-9542-6baf0215170b","type":"ToolEvents"},"toolbar":{"id":"051d8784-8bdc-4ee7-89dd-c22a6d7ba578","type":"Toolbar"},"width":800,"x_mapper_type":"auto","x_range":{"id":"9977522a-7852-4ef3-b6ee-fe9db622f063","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"878b0e5f-7eac-4d75-9320-2457c1ebb915","type":"Range1d"}},"id":"99531a51-adcd-447d-a9f3-4f2cf4ae41c3","subtype":"Chart","type":"Plot"},{"attributes":{"dimension":1,"plot":{"id":"99531a51-adcd-447d-a9f3-4f2cf4ae41c3","subtype":"Chart","type":"Plot"},"ticker":{"id":"aaad44ae-1ddc-4a79-a3f0-95a635c3cab2","type":"BasicTicker"}},"id":"131e1001-c2ff-4ff9-ba05-392a889486ea","type":"Grid"},{"attributes":{"plot":{"id":"99531a51-adcd-447d-a9f3-4f2cf4ae41c3","subtype":"Chart","type":"Plot"},"ticker":{"id":"84152f4e-76ca-45f3-ad51-67d930a1f7b5","type":"BasicTicker"}},"id":"efc81310-1aac-423f-b136-cf4dd4a091c3","type":"Grid"},{"attributes":{"plot":null,"text":"Fuel efficiency of selected vehicles from 1970-1982"},"id":"6d972a12-611a-4e92-960b-b30b3e6a76f2","type":"Title"},{"attributes":{"callback":null,"overlay":{"id":"831b769a-dd18-4ba5-abd5-b79e1f04897f","type":"PolyAnnotation"},"plot":{"id":"99531a51-adcd-447d-a9f3-4f2cf4ae41c3","subtype":"Chart","type":"Plot"}},"id":"ee240dbe-6cf6-4258-bc3f-9064177f1508","type":"LassoSelectTool"},{"attributes":{"data_source":{"id":"274f21fe-5e85-4e08-afa1-beaecd49260b","type":"ColumnDataSource"},"glyph":{"id":"c4cf96ea-f261-457c-aeac-e93df3c1cd10","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"ae56caba-d9c4-4a08-9aef-3b261d8fc815","type":"GlyphRenderer"},{"attributes":{"plot":{"id":" ...

# %%
import pandas as pd
import bokeh

from bokeh.charts import Scatter, Histogram
from bokeh.models import HoverTool, ColumnDataSource
from bokeh.io     import output_notebook, show

from bokeh.sampledata.autompg import autompg

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2935b065-9f57-48df-b449-a02994d28881">Loading BokehJS ...</span>
#     </div>

# %%
bokeh.__version__
# Out:
# '0.12.2'

# %%
autompg['make'] = pd.Series((n.split()[0] for n in autompg.name), 
                            index=autompg.index)
subset     = autompg[autompg.make.isin('ford volkswagen honda'.split())]
subset_cds = ColumnDataSource(subset)

# %%
subset.make
# Out:
# 4            ford
# 5            ford
# 17           ford
# 19     volkswagen
# 25           ford
#           ...
# 377         honda
# 378         honda
# 383          ford
# 387          ford
# 390          ford
# Name: make, dtype: object

# %%
subset
# Out:
#       mpg  cyl  displ   hp  weight  accel  yr  origin  \
# 4    17.0    8  302.0  140    3449   10.5  70       1
# 5    15.0    8  429.0  198    4341   10.0  70       1
# 17   21.0    6  200.0   85    2587   16.0  70       1
# 19   26.0    4   97.0   46    1835   20.5  70       2
# 25   10.0    8  360.0  215    4615   14.0  70       1
# ..    ...  ...    ...  ...     ...    ...  ..     ...
# 377  38.0    4   91.0   67    1965   15.0  82       3
# 378  32.0    4   91.0   67    1965   15.7  82       3
# 383  22.0    6  232.0  112    2835   14.7  82       1
# 387  27.0    4  140.0   86    2790   15.6  82       1
# 390  28.0    4  120.0   79    2625   18.6  82       1
#
#                              name        make
# 4                     ford torino        ford
# 5                ford galaxie 500        ford
# 17                  ford maverick        ford
# 19   volkswagen 1131 deluxe sedan  volkswagen
# 25                      ford f250        ford
# ..                            ...         ...
# 377                   honda civic       honda
# 378            honda civic (auto)       honda
# 383                ford granada l        ford
# 387               ford mustang gl        ford
# 390                   ford ranger        ford
#
# [76 rows x 10 columns]

# %%
tooltips = [
      ('Make','@make'),
      ('MPG', '@mpg'),
      ('hp',  '@hp')
    ]

s = Scatter(data=subset,
            x='yr', y='mpg', color='make',
            height=400, width=600,
            title='Fuel efficiency of selected vehicles from 1970-1982',
            tools='box_zoom, lasso_select, save, reset',
            tooltips=tooltips)

show(s)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="34a5fe00-95c8-42b5-8cc3-8358e2c28082"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#34a5fe00-95c8-42b5-8cc3-8358e2c28082").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("34a5fe00-95c8-42b5-8cc3-8358e2c28082");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '34a5fe00-95c8-42b5-8cc3-8358e2c28082' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"5c63203f-ad1c-4783-9c9e-69d89bb3d7e3":{"roots":{"references":[{"attributes":{"overlay":{"id":"ad0da2c8-e02c-4016-b360-6a6f579b5008","type":"BoxAnnotation"},"plot":{"id":"d58a3f48-cbcd-4859-8058-8577ff6bc879","subtype":"Chart","type":"Plot"}},"id":"91e64a94-4a17-4f65-9b18-83cb4106cf1c","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"},{"make":"ford"}],"make":["ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford","ford"],"x_values":[70,70,70,70,71,71,71,71,72,72,72,72,73,73,73,73,73,74,74,74,75,75,75,75,75,76,76,76,76,76,77,77,77,78,78,78,78,79,79,79,80,81,81,81,82,82,82,82],"y_values":[17.0,15.0,21.0,10.0,19.0,14.0,13.0,18.0,21.0,14.0,13.0,22.0,14.0,13.0,18.0,12.0,19.0,26.0,16.0,14.0,15.0,14.0,13.0,23.0,18.0,14.5,24.0,18.0,26.5,13.0,18.5,16.0,25.5,36.1,20.2,25.1,18.1,22.3,17.6,15.5,26.4,34.4,29.9,20.2,24.0,22.0,27.0,28.0]}},"id":"2d29c9c5-91ba-4c7f-8dfa-2c15b462c6ed","type":"ColumnDataSource"},{"attributes":{},"id":"e746ed27-865d-413a-aa76-d85260948f9d","type":"BasicTickFormatter"},{"attributes":{},"id":"59ad9756-701b-4605-84aa-88ac965452f9","type":"BasicTicker"},{"attributes":{"callback":null,"end":83.2,"start":68.8},"id":"e528dd84-e257-4c3b-8540-3c04da8e2e66","type":"Range1d"},{"attributes":{"data_source":{"id":"2d29c9c5-91ba-4c7f-8dfa-2c15b462c6ed","type":"ColumnDataSource"},"glyph":{"id":"672d7601-879c-4333-ab38-e32173b3f6b5","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"50527cd1-e395-47e3-be68-cb49e0379141","type":"GlyphRenderer"},{"attributes":{"callback":null,"plot":{"id":"d58a3f48-cbcd-4859-8058-8577ff6bc879","subtype":"Chart","type":"Plot"},"tooltips":[["Make","@make"],["MPG","@mpg"],["hp","@hp"]]},"id":"50ed9ca1-8f14-4e5a-b341-9118d5470ffa","type":"HoverTool"},{"attributes":{"legends":[["ford",[{"id":"50527cd1-e395-47e3-be68-cb49e0379141","type":"GlyphRenderer"}]],["volkswagen",[{"id":"38d9aef7-abd6-476d-bb30-666e8ad2daf7","type":"GlyphRenderer"}]],["honda",[{"id":"7229ae3e-bc53-4cfd-91f2-ed9e77a37d9d","type":"GlyphRenderer"}]]],"location":"top_left","plot":{"id":"d58a3f48-cbcd-4859-8058-8577ff6bc879","subtype":"Chart","type":"Plot"}},"id":"c43a51de-c9a9-441a-8e27-23bdb0cb01f6","type":"Legend"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"91e64a94-4a17-4f65-9b18-83cb4106cf1c","type":"BoxZoomTool"},{"id":"a71afaf4-e350-4cad-a309-d073416f9318","type":"LassoSelectTool"},{"id":"f1402b17-b329-4baa-9296-7f2244c2d803","type":"SaveTool"},{"id":"6b073db8-d026-4ba1-95c6-2a8b1dee6e0a","type":"ResetTool"},{"id":"50ed9ca1-8f14-4e5a-b341-9118d5470ffa","type":"HoverTool"}]},"id":"0fcfa18f-1b69-4b29-9d4c-0153fe516065","type":"Toolbar"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#407ee7"},"line_color":{"value":"#407ee7"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"d438b2 ...

# %% [markdown]
# Machine Learning with Scikit-Learn
# ----------------------------------

# %%
from sklearn.svm          import SVC                    as support_vector_classifier
from sklearn.ensemble     import RandomForestClassifier as random_forest_classifier
from sklearn.neighbors    import KNeighborsClassifier   as knn_classifier
from sklearn.linear_model import LinearRegression       as linear_regression_classifier

from sklearn.cross_validation import train_test_split

# %%
train, test = train_test_split(autompg, train_size=0.80, random_state=123)
train = train.copy()
test  = test.copy()

# %% [markdown]
# ### Linear Regression Model

# %%
model = linear_regression_classifier()
model.fit(train['cyl displ hp weight accel yr'.split()],
          train['mpg'].values.ravel())
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
model.score(test['cyl displ hp weight accel yr'.split()],
#            test['mpg'].astype(int).values.ravel()) # for discrete predictions
            test['mpg'].values.ravel())              # for continuous predictions
# Out:
# 0.75077542748160853

# %%
predictions = model.predict(test['cyl displ hp weight accel yr'.split()])
predictions
# Out:
# array([ 16.93513471,  31.44386166,  13.92513989,  25.33100232,
#         30.86517173,  16.12912297,  29.84316806,  20.79424901,
#         17.51682663,  33.5962678 ,  15.16484689,  24.05681003,
#         13.43861853,  30.4849891 ,  15.96175622,  22.14058281,
#         29.18249959,   7.26444002,  12.34592112,  14.11414099,
#         22.31888799,  28.78553786,  29.70553983,  35.29035859,
#         34.53708373,  16.04079521,  26.86016519,  31.90293837,
#         22.70010858,  27.39754987,  23.10237142,  31.48471994,
#         17.0945224 ,  20.83682113,  27.73349153,  28.37221631,
#         27.18683665,  27.98877592,  26.11857502,  11.08719175,
#         17.4036681 ,  23.45466615,  25.0567287 ,  21.985068  ,
#         20.55618207,  20.54065738,  28.84321132,  29.74538267,
#         24.29508899,  20.39074464,  20.98390062,  33.4709278 ,
#         16.27399269,  22.37692882,  22.76363708,  14.67741727,
#          7.73764472,  24.38242977,  19.44958426,  30.11714922,
#         16.5131058 ,   6.38634806,  24.59175118,  27.26877553,
#         20.30193067,  33.77916119,  30.9261231 ,  24.59543879,
#         26.23317754,  22.89863311,  25.04347344,  27.96854099,
#         25.57556152,  11.91524446,  26.96353645,  30.35319343,
#         28.79986239,  13.57871975,  21.44849095])

# %%
test['mpg']
# Out:
# 220    17.0
# 245    39.4
# 134    16.0
# 147    24.0
# 390    28.0
#        ...
# 274    21.6
# 318    37.0
# 380    25.0
# 114    15.0
# 189    22.0
# Name: mpg, dtype: float64

# %%
h = Histogram(predictions - test.mpg, height=400)
show(h)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="b41e2146-2ba8-47a6-ad31-31c54e9ea266"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#b41e2146-2ba8-47a6-ad31-31c54e9ea266").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b41e2146-2ba8-47a6-ad31-31c54e9ea266");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b41e2146-2ba8-47a6-ad31-31c54e9ea266' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"8ce594a6-ed5a-4583-bf5b-a72a93a454fa":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"f90bd80c-919f-4189-9136-c1636d66b8dd","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"df8b6aac-158b-4e82-b3b4-9d3f8fdf49fa","type":"ColumnDataSource"},"glyph":{"id":"5b9dd109-0c89-49ad-b4ff-75ddab257776","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"6d2d2fa2-df14-4bb5-ad1b-4f9dc718207f","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"147ca2dc-e549-48b4-8399-fd7ad116cfbd","type":"ColumnDataSource"},"glyph":{"id":"8ed7c7dc-2ade-484c-8695-723b8db059cd","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"ba951776-2d5c-4125-9a1c-89f693cef85e","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(2.5, 4.8]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[18.0],"label":["(2.5, 4.8]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.257567779627559],"x":["3.65"],"y":[9.0]}},"id":"147ca2dc-e549-48b4-8399-fd7ad116cfbd","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(-2.0, 0.3]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[20.0],"label":["(-2.0, 0.3]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.257567779627559],"x":["-0.85"],"y":[10.0]}},"id":"1a50011d-ec78-44a2-af14-dfb157f18eeb","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(-6.5, -4.2]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[2.0],"label":["(-6.5, -4.2]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.257567779627558],"x":["-5.35"],"y":[1.0]}},"id":"7c681354-5f32-44c3-ae08-a106b51fdd79","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3b45df4f-6184-42d1-bbf4-c6936f38ae5b","type":"Rect"},{"attributes":{"plot":null,"text":null},"id":"d1675644-24f5-4ca4-a1e8-c1c6356f5fd6","type":"Title"},{"attributes":{"axis_label":"Count( Mpg )","formatter":{"id":"1ba8d413-18db-4648-b0e7-402d1fa5342f","type":"BasicTickFormatter"},"plot":{"id":"13a3b1ae-24a9-446b-87bf-e80482e5a67a","subtype":"Chart","type":"Plot"},"ticker":{"id":"568795e1-8766-4bd9-8b9c-f927b1b060ce","type":"BasicTicker"}},"id":"1393be71-1326-4796-a95d-6d5b19d3bbcf","type":"LinearAxis"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5b9dd109-0c89-49ad-b4ff-75ddab257776","type":"Rect"},{"attributes":{"data_source":{"id":"1a2dacee-866a-42b4-a386-9db4387ddeca","type":"ColumnDataSource"},"glyph":{"id":"9135ec36-a081-465e-a326-b0c8714e9983","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"01999b1a-9da7-4107-ac91-91850a34e7c8","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"13a3b1ae-24a9-446b-87bf-e80482e5a67a","subtype":"Chart","type":"Plot"}},"id":"529f82a3-a26f-4228-b04c-c954fbfaadf7","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"dd4d99f4-59d1-4da7-a4ea-6731a457bcdd","type":"ColumnDataSource"},"glyph":{"id":"e4a3036b-9feb-4afb-b268-1641590 ...

# %%
delta          = predictions - test.mpg
test['mpg_lr'] = predictions
test['lr']     = delta
test[delta.abs() > 5]
# Out:
#       mpg  cyl  displ   hp  weight  accel  yr  origin  \
# 245  39.4    4   85.0   70    2070   18.6  78       3
# 327  44.6    4   91.0   67    1850   13.8  80       3
# 273  17.0    6  163.0  125    3140   13.6  78       2
# 240  21.5    4  121.0  110    2600   12.8  77       2
# 307  41.5    4   98.0   76    2144   14.7  80       2
# ..    ...  ...    ...  ...     ...    ...  ..     ...
# 42   13.0    8  400.0  170    4746   12.0  71       1
# 41   12.0    8  383.0  180    4955   11.5  71       1
# 272  20.3    5  131.0  103    2830   15.9  78       2
# 274  21.6    4  121.0  115    2795   15.7  78       2
# 318  37.0    4  119.0   92    2434   15.0  80       3
#
#                          name    make     mpg_lr         lr
# 245            datsun b210 gx  datsun  31.443862  -7.956138
# 327       honda civic 1500 gl   honda  33.596268 -11.003732
# 273               volvo 264gl   volvo  24.056810   7.056810
# 240                  bmw 320i     bmw  26.860165   5.360165
# 307                 vw rabbit      vw  31.902938  -9.597062
# ..                        ...     ...        ...        ...
# 42   ford country squire (sw)    ford   7.737645  -5.262355
# 41          dodge monaco (sw)   dodge   6.386348  -5.613652
# 272                 audi 5000    audi  26.233178   5.933178
# 274                saab 99gle    saab  26.963536   5.363536
# 318      datsun 510 hatchback  datsun  30.353193  -6.646807
#
# [16 rows x 12 columns]

# %% [markdown]
# ### Random Forest Classifier

# %%
model = random_forest_classifier(n_estimators=100)
model.fit(train['cyl displ hp weight accel yr'.split()],
          train['mpg'].astype(int).values.ravel())
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %% [markdown]
# So how does Random Forest compare to Linear Regression?

# %%
model.score(test['cyl displ hp weight accel yr'.split()],
            test['mpg'].astype(int).values.ravel()) # for discrete predictions
#            test['mpg'].values.ravel())              # for continuous predictions
# Out:
# 0.12658227848101267

# %%
predictions = model.predict(test['cyl displ hp weight accel yr'.split()])
predictions
# Out:
# array([15, 31, 14, 23, 31, 18, 23, 17, 15, 31, 16, 20, 15, 30, 15, 22, 24,
#        13, 14, 15, 18, 29, 26, 39, 31, 15, 24, 32, 23, 26, 21, 27, 19, 19,
#        19, 27, 24, 32, 23, 11, 15, 20, 22, 30, 18, 15, 26, 28, 21, 20, 21,
#        38, 16, 17, 20, 16, 13, 21, 23, 31, 16, 12, 24, 24, 17, 39, 34, 20,
#        20, 19, 24, 35, 25, 13, 19, 23, 24, 13, 20])

# %%
delta = predictions - test.mpg
test['mpg_rf'] = predictions
test['rf'] = delta
test[delta.abs() > 5]
# Out:
#       mpg  cyl  displ  hp  weight  accel  yr  origin  \
# 245  39.4    4   85.0  70    2070   18.6  78       3
# 327  44.6    4   91.0  67    1850   13.8  80       3
# 343  37.0    4   85.0  65    1975   19.4  81       3
# 307  41.5    4   98.0  76    2144   14.7  80       2
# 381  38.0    6  262.0  85    3015   17.0  82       1
# 329  29.8    4   89.0  62    1845   15.3  80       2
# 318  37.0    4  119.0  92    2434   15.0  80       3
#
#                                   name        make     mpg_lr         lr  \
# 245                     datsun b210 gx      datsun  31.443862  -7.956138
# 327                honda civic 1500 gl       honda  33.596268 -11.003732
# 343                     datsun 210 mpg      datsun  34.537084  -2.462916
# 307                          vw rabbit          vw  31.902938  -9.597062
# 381  oldsmobile cutlass ciera (diesel)  oldsmobile  27.733492 -10.266508
# 329                   vokswagen rabbit   vokswagen  33.779161   3.979161
# 318               datsun 510 hatchback      datsun  30.353193  -6.646807
#
#      mpg_rf    rf
# 245      31  -8.4
# 327      31 -13.6
# 343      31  -6.0
# 307      32  -9.5
# 381      19 -19.0
# 329      39   9.2
# 318      23 -14.0

# %%
h = Histogram(delta, height=300)
show(h)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="850b6f1d-2e0e-4d1a-9ec1-1396aaed6b8d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#850b6f1d-2e0e-4d1a-9ec1-1396aaed6b8d").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("850b6f1d-2e0e-4d1a-9ec1-1396aaed6b8d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '850b6f1d-2e0e-4d1a-9ec1-1396aaed6b8d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"24205800-54a1-4783-a4ef-a512f95402db":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(-6.5, -4.9]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[2.0],"label":["(-6.5, -4.9]"],"line_alpha":[1.0],"line_color":["black"],"width":[1.5666666666666664],"x":["-5.7"],"y":[1.0]}},"id":"42df8338-6f46-475f-a56d-e2aaec9e1531","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(-14.3, -12.7]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[2.0],"label":["(-14.3, -12.7]"],"line_alpha":[1.0],"line_color":["black"],"width":[1.5666666666666664],"x":["-13.5"],"y":[1.0]}},"id":"29b0de24-fc94-4dca-8a0b-9d8d74a2472f","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(1.4, 2.9]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[10.0],"label":["(1.4, 2.9]"],"line_alpha":[1.0],"line_color":["black"],"width":[1.5666666666666664],"x":["2.15"],"y":[5.0]}},"id":"34c62781-0276-4885-859b-d199ba2ba086","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7caa57ea-bd95-4b8b-83ba-dc6e75d28fe8","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8fc9ccb3-d5fc-406d-bf87-cc938cbae843","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e75b4a09-d808-42b1-bfb7-5904e582ad95","type":"Rect"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"fe4f7812-4d72-4689-af82-259985913134","type":"PanTool"},{"id":"e1e3b1e8-1ef0-418f-9764-2187c4f40f5e","type":"WheelZoomTool"},{"id":"0fbddc6f-c76e-4e62-89b7-c72c99c65449","type":"BoxZoomTool"},{"id":"446338e7-4003-49b7-be1a-370971e09e00","type":"SaveTool"},{"id":"88ca7293-931a-465a-b912-7c138672ceec","type":"ResetTool"},{"id":"9ce53767-8d06-48df-b0ad-3a7a977990e8","type":"HelpTool"}]},"id":"31781068-9039-498a-a5d1-109efaf13eb9","type":"Toolbar"},{"attributes":{"callback":null,"end":20.900000000000002},"id":"fa98fdfe-b5bf-4382-af67-01dcac87a941","type":"Range1d"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"22331786-a3fc-40f3-abbd-fe61abf2f2c6","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(-9.6, -8.0]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[2.0],"label":["(-9.6, -8.0]"],"line_alpha":[1.0],"line_color":["black"],"width":[1.5666666666666664],"x":["-8.8"],"y":[1.0]}},"id":"b4ad8efb-62f2-42bf-8cff-c040adc25d2d","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"60a95eb2-8735-49f6-9fa5-b50cfa9f413d","type":"Rect"},{"attributes":{"dimension":1,"plot":{"id":"0056b0c1-1b99-47c2-88ae-91c6d2f8761d","subtype":"Chart","t ...

# %%
s = Scatter(data=test, x='rf', y='lr', height=300, width=700,
            tools='hover, box_zoom, save, reset',
            title='Comapring model predictions',
            xlabel='Random Forest',
            ylabel='Linear Regression')

hover = s.select(dict(type=HoverTool))

hover.tooltips = [
      ('Make','@make'),
      ('MPG', '@mpg'),
      ('hp',  '@hp')
    ]

show(s)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="fe03862e-9ca4-4ad2-89a6-efdec36f4bf8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#fe03862e-9ca4-4ad2-89a6-efdec36f4bf8").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("fe03862e-9ca4-4ad2-89a6-efdec36f4bf8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'fe03862e-9ca4-4ad2-89a6-efdec36f4bf8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"e7f7bef7-8deb-48fb-b918-79505d40c46a":{"roots":{"references":[{"attributes":{"plot":{"id":"10fbb0cd-0995-4335-b5fc-ea52540abfbe","subtype":"Chart","type":"Plot"}},"id":"affa9384-09d4-40ab-b0f6-4548f0795a69","type":"ResetTool"},{"attributes":{"data_source":{"id":"8288e036-515f-4b64-bfbd-0b203f462d7e","type":"ColumnDataSource"},"glyph":{"id":"38b4cea3-fe42-4db8-83a3-02cb5a4d2f57","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"649b7fdc-a3d8-49d3-82a6-0db9bdd6304e","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"10fbb0cd-0995-4335-b5fc-ea52540abfbe","subtype":"Chart","type":"Plot"},"ticker":{"id":"df90a6e2-8741-419e-b2dc-32f7d7c43846","type":"BasicTicker"}},"id":"05513c44-86a8-4a75-9fac-528f5a349af0","type":"Grid"},{"attributes":{"plot":{"id":"10fbb0cd-0995-4335-b5fc-ea52540abfbe","subtype":"Chart","type":"Plot"}},"id":"acd94e16-d425-45d1-be55-74a46bf8a315","type":"SaveTool"},{"attributes":{},"id":"8d69eb28-c25e-47ae-be00-70bd281eed3a","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a080d3b7-27d8-4862-a58e-5502fd08a6d1","type":"BoxAnnotation"},{"attributes":{"below":[{"id":"678fde6f-eb15-4a71-9fda-5585b25fbeca","type":"LinearAxis"}],"height":300,"left":[{"id":"f60e4ce3-25b0-473f-bf48-855c66a32460","type":"LinearAxis"}],"renderers":[{"id":"a080d3b7-27d8-4862-a58e-5502fd08a6d1","type":"BoxAnnotation"},{"id":"649b7fdc-a3d8-49d3-82a6-0db9bdd6304e","type":"GlyphRenderer"},{"id":"1a8fc4d7-2dc7-4920-a225-8e15235c8a3d","type":"Legend"},{"id":"678fde6f-eb15-4a71-9fda-5585b25fbeca","type":"LinearAxis"},{"id":"f60e4ce3-25b0-473f-bf48-855c66a32460","type":"LinearAxis"},{"id":"05513c44-86a8-4a75-9fac-528f5a349af0","type":"Grid"},{"id":"f5c1f4fa-d72f-4b47-bc8e-09be0d5af48c","type":"Grid"}],"title":{"id":"754d9e22-453c-4cba-ad33-ef781f3fb8ee","type":"Title"},"tool_events":{"id":"a75568f9-12fb-48ec-b53a-22b5093fff51","type":"ToolEvents"},"toolbar":{"id":"948e7a47-da37-460e-9d15-e4f393744962","type":"Toolbar"},"width":700,"x_mapper_type":"auto","x_range":{"id":"10eb7423-367d-416c-86a3-5d31b461345e","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"e7c0dfda-71fa-45f1-ac9a-04399fa62594","type":"Range1d"}},"id":"10fbb0cd-0995-4335-b5fc-ea52540abfbe","subtype":"Chart","type":"Plot"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"38b4cea3-fe42-4db8-83a3-02cb5a4d2f57","type":"Circle"},{"attributes":{"callback":null,"end":12.02,"start":-21.82},"id":"10eb7423-367d-416c-86a3-5d31b461345e","type":"Range1d"},{"attributes":{"dimension":1,"plot":{"id":"10fbb0cd-0995-4335-b5fc-ea52540abfbe","subtype":"Chart","type":"Plot"},"ticker":{"id":"8d69eb28-c25e-47ae-be00-70bd281eed3a","type":"BasicTicker"}},"id":"f5c1f4fa-d72f-4b47-bc8e-09be0d5af48c","type":"Grid"},{"attributes":{},"id":"a75568f9-12fb-48ec-b53a-22b5093fff51","type":"ToolEvents"},{"attributes":{"axis_label":"Random Forest","formatter":{"id":"ac60e2c1-8b31-4982-9f16-0d38fce57e37","type":"BasicTickFormatter"},"plot":{"id":"10fbb0cd-0995-4335-b5fc-ea52540abfbe","subtype":"Chart","type":"Plot"},"ticker":{"id":"df90a6e2-8741-419e-b2dc-32f7d7c43846","type":"BasicTicker"}},"id":"678fde6f-eb15-4a71-9fda-5585b25fbeca","type":"LinearAxis"},{"attributes":{"location":"top_left","plot":{"id":"10fbb0cd-0995-4335-b5fc-ea52540abfbe","subtype":"Chart","type":"Plot"}},"id":"1a8fc4d7-2dc7-4920-a225-8e15235c8a3d","type":"Legend"},{"attributes":{"callback":null,"plot":{"id":"10fbb0cd-0995-4335-b5fc-ea52540abfbe","subtype":"Chart","type":"Plot"},"tooltips":[["Make","@make"],["MPG","@mpg"],["hp", ...

# %% [markdown]
# Summary
# =======
# In this first lesson we explored a simple data analysis workflow and made use of three of the most popular packages in your Anaconda Open Data Science tool box:
#
# * Pandas for data import and processing
# * Bokeh for data visualization
# * Scikit-Learn for machine learning and predictive modeling

# %% [markdown]
# Exercises
# =========
# 1. Run this notebook one cell at a time (by pressing CTRL-ENTER) and try experimenting with parameters. Interact with the visualizations.
#
# 2. Modify the scatter plot to examine different dimensions, such as *Year* vs. *Horsepower*, or *Displacement* vs. *Horsepower*.
#
# 3. Modify which features the `HoverTool` displays.
#
# 4. Try training the model with fewer features (e.g. try just *Displacement* and *Weight*) -- remember that when you exercise it to generate predictions you can only provide those features.
#
# 5. Try using the *K-Nearest Neighbor* or *Support Vector Classifier*.
